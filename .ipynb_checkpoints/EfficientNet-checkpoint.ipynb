# %%
import os
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
import logging
from concurrent.futures import ThreadPoolExecutor

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader as TorchDataLoader
from torch.utils.data import WeightedRandomSampler
import kornia
from PIL import Image

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import seaborn as sns  # For confusion matrix heatmap

logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s: %(message)s')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ---------------------------- Data Augmentation (TorchVision) ----------------------------
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomRotation(degrees=15),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# ---------------------------- Fingerprint Dataset ----------------------------
class FingerprintDataset(Dataset):
    """
    Holds (image, label) pairs and applies either train_transform or eval_transform.
    """
    def __init__(self, images, labels, is_train=True):
        self.images = images
        self.labels = labels
        self.is_train = is_train
        self.transform = train_transform if is_train else eval_transform
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img = self.images[idx]
        lbl = self.labels[idx]
        img_t = self.transform(img)
        return img_t, lbl

# ---------------------------- Directory Data Loader ----------------------------
class DataLoaderCustom:
    def __init__(self, dataset_dirs, num_threads=8):
        self.dataset_dirs = dataset_dirs
        self.num_threads = num_threads

    def load_dataset(self):
        images = []
        labels = []
        with ThreadPoolExecutor(max_workers=self.num_threads) as executor:
            futures = [executor.submit(self._process_dataset_dir, d) for d in self.dataset_dirs]
            for f in futures:
                sub_imgs, sub_lbls = f.result()
                images.extend(sub_imgs)
                labels.extend(sub_lbls)
        return images, labels

    def extract_label_from_filename(self, filename):
        lower_file = filename.lower()
        for finger in ["thumb", "index", "middle", "ring", "little"]:
            if finger in lower_file:
                return finger.capitalize()
        return None

    def _process_dataset_dir(self, dataset_dir):
        local_images = []
        local_labels = []
        print(f"Processing dataset directory: {dataset_dir}")
        entries = [e for e in os.listdir(dataset_dir) if e.lower() != 'thumbs.db']
        
        if all(not os.path.isdir(os.path.join(dataset_dir, e)) for e in entries):
            # Directory with files only
            for file in entries:
                if file.lower().endswith(('.tif', '.bpm', '.bmp', '.png', '.jpeg', '.jpg')):
                    file_path = os.path.join(dataset_dir, file)
                    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
                    if img is not None:
                        label_extracted = self.extract_label_from_filename(file)
                        if label_extracted is None:
                            label_extracted = os.path.basename(dataset_dir)
                        local_images.append(img)
                        local_labels.append(label_extracted)
                        print(f"  Loaded image: {file} with label: {label_extracted}")
                    else:
                        print(f"  Failed to load image: {file}")
        else:
            # Directory with subfolders
            for label in entries:
                lbl_dir = os.path.join(dataset_dir, label)
                if os.path.isdir(lbl_dir):
                    seen_files = set()
                    for file in os.listdir(lbl_dir):
                        if file.lower().endswith(('.tif', '.bpm', '.bmp', '.png', '.jpeg', '.jpg')):
                            file_path = os.path.join(lbl_dir, file)
                            sz = os.path.getsize(file_path)
                            if sz in seen_files:
                                continue
                            seen_files.add(sz)
                            img = cv2.imread(file_path, cv2.IMREAD_COLOR)
                            if img is not None:
                                local_images.append(img)
                                local_labels.append(label)
                                print(f"  Loaded image: {file} with label: {label}")
                            else:
                                print(f"  Failed to load image: {file}")
                else:
                    print(f"  Skipping non-directory: {label}")
        
        return local_images, local_labels

# ---------------------------- WeightedRandomSampler (Oversampling) ----------------------------
from collections import Counter

def make_weighted_sampler(labels):
    """
    Oversample the rarer classes (Ring, Middle) by weighting each class
    inversely proportional to its frequency.
    """
    freq = Counter(labels)
    total = len(labels)
    class_weights = {cls: total / freq[cls] for cls in freq}
    sample_weights = [class_weights[lbl] for lbl in labels]
    sampler = WeightedRandomSampler(weights=sample_weights,
                                    num_samples=len(labels),
                                    replacement=True)
    return sampler

# ---------------------------- EfficientNet + Classical Edge Features ----------------------------
class CombinedModel(nn.Module):
    """
    1) EfficientNet-B0 backbone (unfrozen),
    2) Sobel edge detection -> (mean, std),
    3) Concatenate => 1280 + 2 = 1282 features,
    4) 2-layer MLP to get final num_classes.
    """
    def __init__(self, num_classes=5):
        super().__init__()
        # Load pretrained EfficientNet-B0
        effnet = models.efficientnet_b0(pretrained=True)
        for p in effnet.parameters():
            p.requires_grad = True  # unfreeze all layers

        # Remove the final classification layer
        # By default, efficientnet_b0 has effnet.classifier = Sequential( Dropout, Linear(1280->1000) )
        # We'll replace it with an identity so we get a [B,1280] embedding.
        effnet.classifier = nn.Identity()

        self.efficientnet_backbone = effnet  # outputs [B,1280] after forward

        # Now define the final MLP for (1282 -> 256 -> num_classes)
        self.classifier = nn.Sequential(
            nn.Linear(1282, 256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        # 1) Deep features from EfficientNet
        deep_feat = self.efficientnet_backbone(x)  # shape [B,1280]

        # 2) Sobel-based classical features
        # We'll do an inline approach: convert x => grayscale => sobel => compute mean, std
        # But x is normalized [B,3,224,224]. We'll "unnormalize" or just assume small color differences won't matter
        # Alternatively, you can re-convert to [0..1], but let's do it with Kornia in the same space.

        gray = kornia.color.rgb_to_grayscale(x)
        blurred = kornia.filters.gaussian_blur2d(gray, kernel_size=(5,5), sigma=(1.0,1.0))
        edges = kornia.filters.sobel(blurred)
        edge_map = torch.sqrt(torch.sum(edges**2, dim=1, keepdim=True))  # [B,1,H,W]

        mean_edge = edge_map.view(edge_map.size(0), -1).mean(dim=1) # [B]
        std_edge  = edge_map.view(edge_map.size(0), -1).std(dim=1)  # [B]
        classical_feats = torch.stack([mean_edge, std_edge], dim=1) # [B,2]

        # 3) Concat => shape [B,1282]
        fused = torch.cat([deep_feat, classical_feats], dim=1)

        # 4) Classify
        logits = self.classifier(fused)
        return logits

# ---------------------------- Model Trainer ----------------------------
class ModelTrainer:
    def __init__(self, num_classes=5, num_epochs=100, lr=1e-4, batch_size=32):
        self.num_classes = num_classes
        self.num_epochs  = num_epochs
        self.lr          = lr
        self.batch_size  = batch_size

        self.model = CombinedModel(num_classes=num_classes).to(device)
        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr)

        self.label_to_idx = {}
        self.idx_to_label = {}

    def fit(self, train_images, train_labels, val_images, val_labels):
        """
        Create Datasets & DataLoaders, oversample ring/middle in train, run training for self.num_epochs.
        """
        # Build label maps
        unique_labels = sorted(list(set(train_labels)))
        self.label_to_idx = {lbl: i for i, lbl in enumerate(unique_labels)}
        self.idx_to_label = {v: k for k, v in self.label_to_idx.items()}

        # Build Datasets
        train_dataset = FingerprintDataset(train_images, train_labels, is_train=True)
        val_dataset   = FingerprintDataset(val_images,   val_labels,   is_train=False)

        # Weighted sampler for training
        sampler = make_weighted_sampler(train_labels)
        train_loader = TorchDataLoader(train_dataset, batch_size=self.batch_size,
                                       sampler=sampler, drop_last=False)
        val_loader   = TorchDataLoader(val_dataset, batch_size=self.batch_size,
                                       shuffle=False, drop_last=False)

        for epoch in range(self.num_epochs):
            self.model.train()
            total_loss = 0.0
            total_samples = 0
            for batch_x, batch_labels_str in train_loader:
                # Convert string labels to numeric
                batch_labels = torch.tensor([self.label_to_idx[lbl] for lbl in batch_labels_str], dtype=torch.long)
                batch_x = batch_x.to(device)
                batch_labels = batch_labels.to(device)

                self.optimizer.zero_grad()
                logits = self.model(batch_x)
                loss = self.criterion(logits, batch_labels)
                loss.backward()
                self.optimizer.step()

                total_loss += loss.item() * batch_x.size(0)
                total_samples += batch_x.size(0)

            avg_loss = total_loss / total_samples
            print(f"Epoch [{epoch+1}/{self.num_epochs}], Loss: {avg_loss:.4f}")
        
        print("Training complete.")

    def evaluate(self, test_images, test_labels):
        """
        Evaluate on test set, printing accuracy & weighted F1.
        """
        test_dataset = FingerprintDataset(test_images, test_labels, is_train=False)
        test_loader = TorchDataLoader(test_dataset, batch_size=self.batch_size, shuffle=False, drop_last=False)

        self.model.eval()
        all_preds = []
        all_truth = []
        with torch.no_grad():
            for batch_x, batch_labels_str in test_loader:
                batch_x = batch_x.to(device)
                logits = self.model(batch_x)
                preds = torch.argmax(logits, dim=1).cpu().numpy()
                all_preds.extend(preds)
                all_truth.extend(batch_labels_str)

        # Convert numeric preds => string
        pred_labels_str = [self.idx_to_label[p] for p in all_preds]

        acc = accuracy_score(all_truth, pred_labels_str)
        f1  = f1_score(all_truth, pred_labels_str, average='weighted', zero_division=0)
        print(f"Test Accuracy: {acc:.2f}")
        print(f"Test F1 Score: {f1:.2f}")
        return pred_labels_str

    def predict(self, images_list):
        """
        Single-image or batch inference. images_list is a list of raw cv2 images.
        """
        self.model.eval()
        dummy_labels = ["Unknown"] * len(images_list)
        dataset = FingerprintDataset(images_list, dummy_labels, is_train=False)
        loader  = TorchDataLoader(dataset, batch_size=len(images_list), shuffle=False, drop_last=False)

        with torch.no_grad():
            for batch_x, _ in loader:
                batch_x = batch_x.to(device)
                logits = self.model(batch_x)
                preds = torch.argmax(logits, dim=1).cpu().numpy()
                # Convert to textual labels
                pred_labels_str = [self.idx_to_label[p] for p in preds]
                return pred_labels_str, logits.cpu().numpy()

# ---------------------------- Main Pipeline ----------------------------
class Pipeline:
    def __init__(self, dataset_dirs, num_epochs=100, lr=1e-4, batch_size=32):
        self.dataset_dirs = dataset_dirs
        self.num_epochs = num_epochs
        self.lr = lr
        self.batch_size = batch_size

        self.data_loader = DataLoaderCustom(dataset_dirs)
        self.model_trainer = None

        self.y_train = []
        self.y_val   = []
        self.y_test  = []
        self.train_imgs = []
        self.val_imgs   = []
        self.test_imgs  = []

    def run(self):
        images, labels = self.data_loader.load_dataset()
        print(f"Loaded {len(images)} images total.")

        # Train-val-test split
        X_temp, X_test, y_temp, y_test = train_test_split(images, labels,
                                                          test_size=0.15, random_state=42, stratify=labels)
        X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp,
                                                          test_size=0.1765, random_state=42, stratify=y_temp)

        self.train_imgs = X_train
        self.val_imgs   = X_val
        self.test_imgs  = X_test
        self.y_train    = y_train
        self.y_val      = y_val
        self.y_test     = y_test

        print(f"Training set: {len(X_train)} images, Validation set: {len(X_val)} images, Test set: {len(X_test)} images")

        # Build & Train
        num_classes = len(set(y_train))
        self.model_trainer = ModelTrainer(num_classes=num_classes,
                                          num_epochs=self.num_epochs,
                                          lr=self.lr,
                                          batch_size=self.batch_size)
        self.model_trainer.fit(X_train, y_train, X_val, y_val)

        # Evaluate
        self.model_trainer.evaluate(X_test, y_test)

# ---------------------------- Helper: Plot Class Distribution ----------------------------
def plot_class_distribution(y_train, y_val, y_test, save_path='class_distribution.png'):
    classes = sorted(list(set(y_train + y_val + y_test)))
    train_counts = [y_train.count(cls) for cls in classes]
    val_counts   = [y_val.count(cls)   for cls in classes]
    test_counts  = [y_test.count(cls)  for cls in classes]

    x = np.arange(len(classes))
    width = 0.25

    plt.figure(figsize=(8, 6))
    plt.bar(x - width, train_counts, width, label='Train')
    plt.bar(x,         val_counts,   width, label='Validation')
    plt.bar(x + width, test_counts,  width, label='Test')

    plt.xlabel('Finger Classes')
    plt.ylabel('Number of Samples')
    plt.title('Class Distribution: Train / Validation / Test')
    plt.xticks(x, classes)
    plt.legend()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

# ---------------------------- Helper: Confusion Matrix & Report ----------------------------
def plot_confusion_matrix_and_report(pipeline, normalize=None, save_path='confusion_matrix.png'):
    test_imgs = pipeline.test_imgs
    test_labels = pipeline.y_test
    trainer = pipeline.model_trainer

    test_dataset = FingerprintDataset(test_imgs, test_labels, is_train=False)
    test_loader = TorchDataLoader(test_dataset, batch_size=trainer.batch_size,
                                  shuffle=False, drop_last=False)

    trainer.model.eval()
    all_preds = []
    all_truth = []
    with torch.no_grad():
        for batch_x, batch_labels_str in test_loader:
            batch_x = batch_x.to(device)
            logits = trainer.model(batch_x)
            preds = torch.argmax(logits, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_truth.extend(batch_labels_str)

    class_labels = sorted(list(trainer.label_to_idx.keys()))
    pred_labels_str = [trainer.idx_to_label[p] for p in all_preds]

    cm = confusion_matrix(all_truth, pred_labels_str, labels=class_labels, normalize=normalize)

    print("\nClassification Report:")
    print(classification_report(all_truth, pred_labels_str, labels=class_labels))

    plt.figure(figsize=(8, 6))
    fmt = '.2f' if normalize else 'd'
    sns.heatmap(cm, annot=True, fmt=fmt,
                xticklabels=class_labels, yticklabels=class_labels, cmap='Blues')
    title_str = "Confusion Matrix"
    if normalize:
        title_str += f" (Normalized: {normalize})"
    plt.title(title_str)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

# ---------------------------- Helper: Single Image Inference ----------------------------
def single_image_inference_with_visuals(pipeline, image_path):
    """
    Loads a single image, extracts features using the pipeline's feature extractor,
    applies the pipeline's feature mask (if any), predicts the label,
    AND displays the original vs. processed image side by side.
    """
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not read image from {image_path}")
        return None, None
    
    # (1) Extract fused features, plus the edge map (processed_img) and fingerprint features
    #    Note: process_single_image returns (fused_feat, edge_map, fingerprint_feat)
    fused_feat, edge_map, fingerprint_feat = pipeline.feature_extractor.process_single_image(img)
    
    # (2) Display side-by-side images: Original vs. Edge Map
    plt.figure(figsize=(10, 5))
    # Left subplot: Original (in RGB format)
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.axis("off")

    # Right subplot: Edge Map (grayscale)
    plt.subplot(1, 2, 2)
    plt.imshow(edge_map, cmap="gray")
    plt.title("Processed (Edge Map)")
    plt.axis("off")

    plt.show()

    # (3) Apply feature mask (if any)
    if pipeline.best_feature_mask is not None:
        fused_feat = fused_feat[pipeline.best_feature_mask]

    # (4) Model inference
    X_input = np.array([fused_feat])
    pipeline.model_trainer.model.eval()

    with torch.no_grad():
        X_tensor = torch.tensor(X_input, dtype=torch.float32).to(pipeline.model_trainer.model.fc[0].weight.device)
        logits = pipeline.model_trainer.model(X_tensor)
        softmax_probs = torch.nn.functional.softmax(logits, dim=1)
    
    _, predicted_indices = torch.max(softmax_probs, dim=1)
    predicted_index = predicted_indices[0].item()
    predicted_label = pipeline.model_trainer.idx_to_label[predicted_index]
    
    # (5) Print probabilities
    probs_np = softmax_probs[0].cpu().numpy()
    class_labels = [pipeline.model_trainer.idx_to_label[i] for i in range(len(probs_np))]
    probabilities = {label: float(prob) for label, prob in zip(class_labels, probs_np)}

    print(f"Predicted Label: {predicted_label}")
    print("Probabilities:")
    for cls, prob in probabilities.items():
        print(f"  {cls}: {prob:.4f}")

    return predicted_label, probabilities

# ---------------------------- Example Usage ----------------------------
if __name__ == "__main__":
    dataset_dirs = [
        os.path.expanduser("~/data/SOCOFing/Real")
    ]

    # Create Pipeline using EfficientNet + classical edge features
    pipeline = Pipeline(dataset_dirs, num_epochs=100, lr=1e-4, batch_size=32)
    pipeline.run()
# Out:
# Using device: cuda:0
# Processing dataset directory: /home/zaman-m65/data/SOCOFing/Real
#   Loaded image: 134__M_Left_little_finger.BMP with label: Little
#   Loaded image: 456__M_Right_little_finger.BMP with label: Little
#   Loaded image: 103__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 293__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 110__F_Left_little_finger.BMP with label: Little
#   Loaded image: 80__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 574__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 546__M_Left_index_finger.BMP with label: Index
#   Loaded image: 237__M_Right_little_finger.BMP with label: Little
#   Loaded image: 8__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 533__M_Right_little_finger.BMP with label: Little
#   Loaded image: 106__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 474__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 289__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 176__M_Left_index_finger.BMP with label: Index
#   Loaded image: 146__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 597__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 117__F_Right_little_finger.BMP with label: Little
#   Loaded image: 296__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 454__M_Left_little_finger.BMP with label: Little
#   Loaded image: 410__M_Left_index_finger.BMP with label: Index
#   Loaded image: 248__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 407__M_Left_index_finger.BMP with label: Index
#   Loaded image: 103__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 47__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 433__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 303__F_Left_little_finger.BMP with label: Little
#   Loaded image: 315__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 91__F_Right_little_finger.BMP with label: Little
#   Loaded image: 517__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 364__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 250__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 414__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 192__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 420__M_Left_little_finger.BMP with label: Little
#   Loaded image: 109__F_Left_index_finger.BMP with label: Index
#   Loaded image: 354__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 529__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 2__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 489__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 569__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 596__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 296__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 36__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 71__M_Left_little_finger.BMP with label: Little
#   Loaded image: 564__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 104__M_Right_little_finger.BMP with label: Little
#   Loaded image: 236__M_Left_index_finger.BMP with label: Index
#   Loaded image: 256__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 450__M_Left_little_finger.BMP with label: Little
#   Loaded image: 49__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 299__M_Left_index_finger.BMP with label: Index
#   Loaded image: 410__M_Right_index_finger.BMP with label: Index
#   Loaded image: 41__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 470__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 503__M_Left_little_finger.BMP with label: Little
#   Loaded image: 510__M_Left_index_finger.BMP with label: Index
#   Loaded image: 363__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 116__M_Left_index_finger.BMP with label: Index
#   Loaded image: 69__M_Right_index_finger.BMP with label: Index
#   Loaded image: 355__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 292__M_Right_index_finger.BMP with label: Index
#   Loaded image: 473__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 39__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 329__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 392__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 233__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 387__F_Left_index_finger.BMP with label: Index
#   Loaded image: 64__M_Right_little_finger.BMP with label: Little
#   Loaded image: 155__M_Right_index_finger.BMP with label: Index
#   Loaded image: 369__F_Right_little_finger.BMP with label: Little
#   Loaded image: 236__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 438__M_Right_index_finger.BMP with label: Index
#   Loaded image: 352__M_Right_index_finger.BMP with label: Index
#   Loaded image: 419__F_Left_index_finger.BMP with label: Index
#   Loaded image: 515__M_Left_little_finger.BMP with label: Little
#   Loaded image: 298__M_Right_index_finger.BMP with label: Index
#   Loaded image: 301__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 248__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 427__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 532__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 320__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 552__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 180__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 585__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 142__F_Left_index_finger.BMP with label: Index
#   Loaded image: 255__M_Right_little_finger.BMP with label: Little
#   Loaded image: 357__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 44__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 555__M_Right_little_finger.BMP with label: Little
#   Loaded image: 558__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 596__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 208__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 369__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 63__M_Right_index_finger.BMP with label: Index
#   Loaded image: 410__M_Left_little_finger.BMP with label: Little
#   Loaded image: 438__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 437__M_Left_index_finger.BMP with label: Index
#   Loaded image: 73__M_Right_little_finger.BMP with label: Little
#   Loaded image: 76__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 544__M_Left_little_finger.BMP with label: Little
#   Loaded image: 205__F_Right_little_finger.BMP with label: Little
#   Loaded image: 497__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 380__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 365__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 525__M_Left_index_finger.BMP with label: Index
#   Loaded image: 468__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 337__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 145__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 562__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 54__M_Left_little_finger.BMP with label: Little
#   Loaded image: 489__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 486__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 382__M_Right_index_finger.BMP with label: Index
#   Loaded image: 97__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 58__M_Left_little_finger.BMP with label: Little
#   Loaded image: 552__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 449__F_Left_index_finger.BMP with label: Index
#   Loaded image: 78__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 196__M_Right_index_finger.BMP with label: Index
#   Loaded image: 51__M_Right_index_finger.BMP with label: Index
#   Loaded image: 85__M_Left_little_finger.BMP with label: Little
#   Loaded image: 102__M_Left_index_finger.BMP with label: Index
#   Loaded image: 234__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 432__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 281__M_Right_index_finger.BMP with label: Index
#   Loaded image: 539__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 204__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 138__M_Right_little_finger.BMP with label: Little
#   Loaded image: 304__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 292__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 298__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 599__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 82__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 588__M_Right_index_finger.BMP with label: Index
#   Loaded image: 279__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 397__M_Left_index_finger.BMP with label: Index
#   Loaded image: 557__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 282__M_Right_index_finger.BMP with label: Index
#   Loaded image: 123__M_Left_little_finger.BMP with label: Little
#   Loaded image: 585__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 218__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 443__M_Left_little_finger.BMP with label: Little
#   Loaded image: 384__F_Left_little_finger.BMP with label: Little
#   Loaded image: 266__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 178__M_Left_little_finger.BMP with label: Little
#   Loaded image: 297__M_Right_little_finger.BMP with label: Little
#   Loaded image: 227__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 288__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 257__M_Right_little_finger.BMP with label: Little
#   Loaded image: 63__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 91__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 274__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 224__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 369__F_Left_index_finger.BMP with label: Index
#   Loaded image: 176__M_Left_little_finger.BMP with label: Little
#   Loaded image: 457__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 399__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 424__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 528__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 134__M_Right_index_finger.BMP with label: Index
#   Loaded image: 10__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 459__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 43__F_Left_little_finger.BMP with label: Little
#   Loaded image: 327__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 41__M_Right_index_finger.BMP with label: Index
#   Loaded image: 560__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 95__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 8__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 347__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 72__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 45__M_Left_little_finger.BMP with label: Little
#   Loaded image: 200__M_Left_little_finger.BMP with label: Little
#   Loaded image: 583__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 94__M_Right_little_finger.BMP with label: Little
#   Loaded image: 416__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 533__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 263__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 341__M_Right_index_finger.BMP with label: Index
#   Loaded image: 598__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 287__M_Left_index_finger.BMP with label: Index
#   Loaded image: 575__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 311__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 139__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 497__M_Right_little_finger.BMP with label: Little
#   Loaded image: 199__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 421__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 433__M_Right_little_finger.BMP with label: Little
#   Loaded image: 368__M_Left_index_finger.BMP with label: Index
#   Loaded image: 57__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 152__M_Right_little_finger.BMP with label: Little
#   Loaded image: 25__F_Left_index_finger.BMP with label: Index
#   Loaded image: 447__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 334__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 199__M_Right_little_finger.BMP with label: Little
#   Loaded image: 376__F_Left_little_finger.BMP with label: Little
#   Loaded image: 345__M_Left_little_finger.BMP with label: Little
#   Loaded image: 104__M_Left_little_finger.BMP with label: Little
#   Loaded image: 413__M_Left_little_finger.BMP with label: Little
#   Loaded image: 99__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 179__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 305__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 516__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 28__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 70__M_Right_index_finger.BMP with label: Index
#   Loaded image: 407__M_Right_little_finger.BMP with label: Little
#   Loaded image: 231__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 153__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 14__M_Right_index_finger.BMP with label: Index
#   Loaded image: 54__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 134__M_Left_index_finger.BMP with label: Index
#   Loaded image: 254__M_Right_index_finger.BMP with label: Index
#   Loaded image: 203__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 73__M_Left_little_finger.BMP with label: Little
#   Loaded image: 494__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 196__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 586__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 375__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 177__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 498__M_Right_index_finger.BMP with label: Index
#   Loaded image: 566__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 260__M_Right_index_finger.BMP with label: Index
#   Loaded image: 375__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 469__M_Left_little_finger.BMP with label: Little
#   Loaded image: 147__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 3__M_Left_index_finger.BMP with label: Index
#   Loaded image: 379__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 537__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 8__M_Left_index_finger.BMP with label: Index
#   Loaded image: 439__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 89__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 298__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 358__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 287__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 89__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 480__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 13__F_Right_little_finger.BMP with label: Little
#   Loaded image: 258__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 538__M_Right_index_finger.BMP with label: Index
#   Loaded image: 290__M_Left_index_finger.BMP with label: Index
#   Loaded image: 437__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 323__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 42__F_Right_index_finger.BMP with label: Index
#   Loaded image: 306__M_Right_index_finger.BMP with label: Index
#   Loaded image: 544__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 442__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 193__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 468__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 258__M_Left_index_finger.BMP with label: Index
#   Loaded image: 506__M_Right_index_finger.BMP with label: Index
#   Loaded image: 584__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 544__M_Left_index_finger.BMP with label: Index
#   Loaded image: 576__M_Right_index_finger.BMP with label: Index
#   Loaded image: 129__M_Right_little_finger.BMP with label: Little
#   Loaded image: 539__F_Right_little_finger.BMP with label: Little
#   Loaded image: 131__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 461__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 37__M_Left_little_finger.BMP with label: Little
#   Loaded image: 535__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 253__F_Left_little_finger.BMP with label: Little
#   Loaded image: 52__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 597__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 432__M_Left_index_finger.BMP with label: Index
#   Loaded image: 1__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 205__F_Left_little_finger.BMP with label: Little
#   Loaded image: 210__M_Left_index_finger.BMP with label: Index
#   Loaded image: 509__M_Right_little_finger.BMP with label: Little
#   Loaded image: 583__M_Left_index_finger.BMP with label: Index
#   Loaded image: 174__F_Right_little_finger.BMP with label: Little
#   Loaded image: 142__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 287__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 120__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 309__M_Right_index_finger.BMP with label: Index
#   Loaded image: 369__F_Left_little_finger.BMP with label: Little
#   Loaded image: 316__M_Right_little_finger.BMP with label: Little
#   Loaded image: 263__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 496__M_Right_little_finger.BMP with label: Little
#   Loaded image: 479__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 543__M_Left_little_finger.BMP with label: Little
#   Loaded image: 191__F_Right_little_finger.BMP with label: Little
#   Loaded image: 34__M_Left_index_finger.BMP with label: Index
#   Loaded image: 237__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 212__M_Left_index_finger.BMP with label: Index
#   Loaded image: 25__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 266__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 50__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 341__M_Left_little_finger.BMP with label: Little
#   Loaded image: 291__M_Left_little_finger.BMP with label: Little
#   Loaded image: 519__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 482__M_Right_index_finger.BMP with label: Index
#   Loaded image: 222__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 143__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 69__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 517__M_Right_index_finger.BMP with label: Index
#   Loaded image: 370__M_Right_little_finger.BMP with label: Little
#   Loaded image: 225__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 537__M_Left_little_finger.BMP with label: Little
#   Loaded image: 278__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 573__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 355__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 164__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 492__F_Left_little_finger.BMP with label: Little
#   Loaded image: 400__M_Left_index_finger.BMP with label: Index
#   Loaded image: 527__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 282__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 61__M_Left_index_finger.BMP with label: Index
#   Loaded image: 455__M_Right_index_finger.BMP with label: Index
#   Loaded image: 170__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 99__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 87__M_Left_index_finger.BMP with label: Index
#   Loaded image: 242__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 281__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 284__M_Right_little_finger.BMP with label: Little
#   Loaded image: 87__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 522__M_Left_little_finger.BMP with label: Little
#   Loaded image: 46__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 335__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 65__M_Left_index_finger.BMP with label: Index
#   Loaded image: 413__M_Right_little_finger.BMP with label: Little
#   Loaded image: 131__M_Left_little_finger.BMP with label: Little
#   Loaded image: 485__M_Right_little_finger.BMP with label: Little
#   Loaded image: 17__M_Right_index_finger.BMP with label: Index
#   Loaded image: 135__F_Left_index_finger.BMP with label: Index
#   Loaded image: 224__M_Right_little_finger.BMP with label: Little
#   Loaded image: 373__M_Left_index_finger.BMP with label: Index
#   Loaded image: 78__F_Left_little_finger.BMP with label: Little
#   Loaded image: 268__M_Right_little_finger.BMP with label: Little
#   Loaded image: 198__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 214__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 232__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 32__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 505__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 296__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 280__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 490__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 547__M_Left_index_finger.BMP with label: Index
#   Loaded image: 145__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 299__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 436__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 421__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 170__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 578__M_Right_index_finger.BMP with label: Index
#   Loaded image: 534__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 430__F_Right_little_finger.BMP with label: Little
#   Loaded image: 495__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 244__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 398__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 354__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 132__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 293__F_Left_index_finger.BMP with label: Index
#   Loaded image: 280__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 294__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 365__M_Left_little_finger.BMP with label: Little
#   Loaded image: 95__M_Right_index_finger.BMP with label: Index
#   Loaded image: 433__M_Left_index_finger.BMP with label: Index
#   Loaded image: 158__M_Right_index_finger.BMP with label: Index
#   Loaded image: 37__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 147__M_Left_little_finger.BMP with label: Little
#   Loaded image: 100__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 134__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 62__M_Right_little_finger.BMP with label: Little
#   Loaded image: 53__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 575__M_Left_index_finger.BMP with label: Index
#   Loaded image: 311__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 87__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 240__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 510__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 201__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 224__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 479__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 20__M_Right_index_finger.BMP with label: Index
#   Loaded image: 228__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 309__M_Right_little_finger.BMP with label: Little
#   Loaded image: 16__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 546__M_Right_little_finger.BMP with label: Little
#   Loaded image: 157__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 359__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 188__M_Left_index_finger.BMP with label: Index
#   Loaded image: 39__M_Left_little_finger.BMP with label: Little
#   Loaded image: 171__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 152__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 145__M_Left_little_finger.BMP with label: Little
#   Loaded image: 222__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 485__M_Left_index_finger.BMP with label: Index
#   Loaded image: 191__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 251__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 223__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 396__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 127__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 508__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 144__M_Right_little_finger.BMP with label: Little
#   Loaded image: 206__M_Right_index_finger.BMP with label: Index
#   Loaded image: 320__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 381__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 425__M_Right_index_finger.BMP with label: Index
#   Loaded image: 320__M_Right_index_finger.BMP with label: Index
#   Loaded image: 102__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 401__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 248__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 460__M_Left_little_finger.BMP with label: Little
#   Loaded image: 506__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 528__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 195__M_Left_little_finger.BMP with label: Little
#   Loaded image: 202__M_Left_index_finger.BMP with label: Index
#   Loaded image: 564__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 203__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 595__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 28__M_Right_index_finger.BMP with label: Index
#   Loaded image: 324__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 257__M_Right_index_finger.BMP with label: Index
#   Loaded image: 464__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 407__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 320__M_Left_little_finger.BMP with label: Little
#   Loaded image: 298__M_Left_index_finger.BMP with label: Index
#   Loaded image: 19__M_Right_index_finger.BMP with label: Index
#   Loaded image: 285__M_Left_little_finger.BMP with label: Little
#   Loaded image: 335__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 464__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 281__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 349__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 407__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 366__M_Right_index_finger.BMP with label: Index
#   Loaded image: 400__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 79__M_Right_little_finger.BMP with label: Little
#   Loaded image: 94__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 1__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 241__M_Right_index_finger.BMP with label: Index
#   Loaded image: 68__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 507__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 413__M_Left_index_finger.BMP with label: Index
#   Loaded image: 11__M_Left_index_finger.BMP with label: Index
#   Loaded image: 460__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 188__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 300__F_Left_index_finger.BMP with label: Index
#   Loaded image: 273__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 268__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 158__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 57__M_Left_index_finger.BMP with label: Index
#   Loaded image: 416__M_Right_little_finger.BMP with label: Little
#   Loaded image: 461__F_Right_index_finger.BMP with label: Index
#   Loaded image: 289__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 550__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 543__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 96__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 444__M_Right_index_finger.BMP with label: Index
#   Loaded image: 103__F_Left_index_finger.BMP with label: Index
#   Loaded image: 78__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 228__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 207__M_Right_index_finger.BMP with label: Index
#   Loaded image: 156__F_Left_little_finger.BMP with label: Little
#   Loaded image: 266__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 27__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 336__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 253__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 469__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 243__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 583__M_Right_little_finger.BMP with label: Little
#   Loaded image: 539__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 116__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 34__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 527__M_Left_index_finger.BMP with label: Index
#   Loaded image: 441__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 75__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 107__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 383__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 165__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 179__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 501__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 133__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 235__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 99__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 494__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 461__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 133__M_Left_little_finger.BMP with label: Little
#   Loaded image: 411__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 139__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 66__F_Left_little_finger.BMP with label: Little
#   Loaded image: 177__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 147__M_Left_index_finger.BMP with label: Index
#   Loaded image: 347__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 514__F_Right_index_finger.BMP with label: Index
#   Loaded image: 74__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 83__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 179__M_Right_index_finger.BMP with label: Index
#   Loaded image: 345__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 418__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 249__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 191__F_Right_index_finger.BMP with label: Index
#   Loaded image: 294__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 157__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 337__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 503__M_Left_index_finger.BMP with label: Index
#   Loaded image: 44__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 205__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 456__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 15__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 553__M_Left_little_finger.BMP with label: Little
#   Loaded image: 340__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 593__M_Right_little_finger.BMP with label: Little
#   Loaded image: 222__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 327__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 28__M_Left_index_finger.BMP with label: Index
#   Loaded image: 195__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 108__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 346__M_Right_little_finger.BMP with label: Little
#   Loaded image: 513__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 73__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 60__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 349__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 357__M_Right_index_finger.BMP with label: Index
#   Loaded image: 70__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 539__F_Left_little_finger.BMP with label: Little
#   Loaded image: 290__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 507__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 550__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 32__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 229__M_Right_little_finger.BMP with label: Little
#   Loaded image: 321__M_Left_index_finger.BMP with label: Index
#   Loaded image: 196__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 24__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 77__M_Right_little_finger.BMP with label: Little
#   Loaded image: 71__M_Right_index_finger.BMP with label: Index
#   Loaded image: 185__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 471__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 115__F_Left_little_finger.BMP with label: Little
#   Loaded image: 582__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 455__M_Left_little_finger.BMP with label: Little
#   Loaded image: 398__M_Right_index_finger.BMP with label: Index
#   Loaded image: 466__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 130__F_Left_little_finger.BMP with label: Little
#   Loaded image: 444__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 568__M_Right_little_finger.BMP with label: Little
#   Loaded image: 424__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 438__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 262__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 397__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 569__M_Left_little_finger.BMP with label: Little
#   Loaded image: 518__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 481__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 348__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 593__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 520__M_Left_index_finger.BMP with label: Index
#   Loaded image: 298__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 394__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 146__M_Left_little_finger.BMP with label: Little
#   Loaded image: 271__M_Left_index_finger.BMP with label: Index
#   Loaded image: 310__M_Left_little_finger.BMP with label: Little
#   Loaded image: 244__M_Right_index_finger.BMP with label: Index
#   Loaded image: 190__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 202__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 479__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 192__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 211__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 10__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 160__M_Right_little_finger.BMP with label: Little
#   Loaded image: 11__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 344__M_Right_index_finger.BMP with label: Index
#   Loaded image: 596__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 347__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 308__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 561__M_Right_index_finger.BMP with label: Index
#   Loaded image: 315__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 1__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 160__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 45__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 590__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 521__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 362__M_Right_little_finger.BMP with label: Little
#   Loaded image: 196__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 229__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 307__M_Left_little_finger.BMP with label: Little
#   Loaded image: 159__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 66__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 305__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 142__F_Right_little_finger.BMP with label: Little
#   Loaded image: 393__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 20__M_Left_index_finger.BMP with label: Index
#   Loaded image: 159__M_Left_little_finger.BMP with label: Little
#   Loaded image: 133__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 181__M_Right_little_finger.BMP with label: Little
#   Loaded image: 49__M_Left_index_finger.BMP with label: Index
#   Loaded image: 320__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 344__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 547__M_Left_little_finger.BMP with label: Little
#   Loaded image: 149__F_Left_little_finger.BMP with label: Little
#   Loaded image: 167__M_Right_little_finger.BMP with label: Little
#   Loaded image: 166__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 560__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 572__F_Left_index_finger.BMP with label: Index
#   Loaded image: 354__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 567__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 396__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 274__M_Left_index_finger.BMP with label: Index
#   Loaded image: 330__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 366__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 269__M_Left_little_finger.BMP with label: Little
#   Loaded image: 87__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 545__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 556__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 533__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 74__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 355__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 380__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 312__M_Right_little_finger.BMP with label: Little
#   Loaded image: 240__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 324__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 279__M_Left_index_finger.BMP with label: Index
#   Loaded image: 534__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 481__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 260__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 9__M_Left_index_finger.BMP with label: Index
#   Loaded image: 365__M_Left_index_finger.BMP with label: Index
#   Loaded image: 46__M_Left_index_finger.BMP with label: Index
#   Loaded image: 181__M_Left_index_finger.BMP with label: Index
#   Loaded image: 67__F_Right_index_finger.BMP with label: Index
#   Loaded image: 577__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 205__F_Left_index_finger.BMP with label: Index
#   Loaded image: 198__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 296__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 392__M_Right_index_finger.BMP with label: Index
#   Loaded image: 533__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 355__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 432__M_Right_little_finger.BMP with label: Little
#   Loaded image: 237__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 477__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 486__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 347__M_Left_little_finger.BMP with label: Little
#   Loaded image: 364__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 4__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 535__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 184__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 190__M_Left_little_finger.BMP with label: Little
#   Loaded image: 221__M_Right_little_finger.BMP with label: Little
#   Loaded image: 593__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 584__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 366__M_Left_index_finger.BMP with label: Index
#   Loaded image: 232__M_Right_little_finger.BMP with label: Little
#   Loaded image: 149__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 114__F_Right_index_finger.BMP with label: Index
#   Loaded image: 309__M_Left_index_finger.BMP with label: Index
#   Loaded image: 156__F_Right_little_finger.BMP with label: Little
#   Loaded image: 227__M_Right_little_finger.BMP with label: Little
#   Loaded image: 187__M_Right_index_finger.BMP with label: Index
#   Loaded image: 252__F_Right_little_finger.BMP with label: Little
#   Loaded image: 327__M_Right_index_finger.BMP with label: Index
#   Loaded image: 295__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 391__M_Right_index_finger.BMP with label: Index
#   Loaded image: 550__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 179__M_Left_little_finger.BMP with label: Little
#   Loaded image: 333__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 178__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 78__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 515__M_Right_index_finger.BMP with label: Index
#   Loaded image: 450__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 483__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 310__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 204__F_Left_little_finger.BMP with label: Little
#   Loaded image: 132__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 393__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 97__M_Left_little_finger.BMP with label: Little
#   Loaded image: 328__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 200__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 256__M_Right_little_finger.BMP with label: Little
#   Loaded image: 190__M_Right_little_finger.BMP with label: Little
#   Loaded image: 25__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 576__M_Left_index_finger.BMP with label: Index
#   Loaded image: 33__M_Left_index_finger.BMP with label: Index
#   Loaded image: 84__M_Left_index_finger.BMP with label: Index
#   Loaded image: 469__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 52__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 467__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 12__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 260__M_Right_little_finger.BMP with label: Little
#   Loaded image: 175__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 127__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 598__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 558__M_Left_little_finger.BMP with label: Little
#   Loaded image: 188__M_Right_little_finger.BMP with label: Little
#   Loaded image: 108__M_Left_index_finger.BMP with label: Index
#   Loaded image: 229__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 174__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 281__M_Right_little_finger.BMP with label: Little
#   Loaded image: 149__F_Right_index_finger.BMP with label: Index
#   Loaded image: 278__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 273__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 430__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 56__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 316__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 54__M_Right_little_finger.BMP with label: Little
#   Loaded image: 422__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 387__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 202__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 380__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 217__M_Left_little_finger.BMP with label: Little
#   Loaded image: 310__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 429__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 270__M_Right_little_finger.BMP with label: Little
#   Loaded image: 494__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 426__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 595__M_Left_index_finger.BMP with label: Index
#   Loaded image: 112__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 332__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 137__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 557__M_Right_index_finger.BMP with label: Index
#   Loaded image: 172__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 357__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 524__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 394__M_Left_index_finger.BMP with label: Index
#   Loaded image: 96__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 245__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 291__M_Left_index_finger.BMP with label: Index
#   Loaded image: 507__M_Left_little_finger.BMP with label: Little
#   Loaded image: 245__M_Left_index_finger.BMP with label: Index
#   Loaded image: 223__M_Left_little_finger.BMP with label: Little
#   Loaded image: 230__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 539__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 386__M_Right_little_finger.BMP with label: Little
#   Loaded image: 463__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 132__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 196__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 373__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 133__M_Right_index_finger.BMP with label: Index
#   Loaded image: 283__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 204__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 562__F_Left_index_finger.BMP with label: Index
#   Loaded image: 275__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 246__M_Left_index_finger.BMP with label: Index
#   Loaded image: 379__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 241__M_Left_index_finger.BMP with label: Index
#   Loaded image: 151__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 59__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 317__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 220__F_Left_index_finger.BMP with label: Index
#   Loaded image: 388__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 221__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 81__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 310__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 589__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 46__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 464__M_Left_little_finger.BMP with label: Little
#   Loaded image: 452__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 8__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 275__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 450__M_Right_index_finger.BMP with label: Index
#   Loaded image: 536__F_Left_little_finger.BMP with label: Little
#   Loaded image: 243__M_Right_index_finger.BMP with label: Index
#   Loaded image: 76__F_Right_index_finger.BMP with label: Index
#   Loaded image: 541__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 254__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 107__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 295__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 7__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 55__M_Left_little_finger.BMP with label: Little
# ...
#   Loaded image: 390__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 44__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 9__M_Left_little_finger.BMP with label: Little
#   Loaded image: 55__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 21__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 454__M_Left_index_finger.BMP with label: Index
#   Loaded image: 190__M_Right_index_finger.BMP with label: Index
#   Loaded image: 140__F_Right_index_finger.BMP with label: Index
#   Loaded image: 440__M_Right_little_finger.BMP with label: Little
#   Loaded image: 24__F_Left_little_finger.BMP with label: Little
#   Loaded image: 272__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 21__M_Right_little_finger.BMP with label: Little
#   Loaded image: 63__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 261__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 497__M_Right_index_finger.BMP with label: Index
#   Loaded image: 15__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 296__M_Right_little_finger.BMP with label: Little
#   Loaded image: 513__M_Right_index_finger.BMP with label: Index
#   Loaded image: 249__M_Left_little_finger.BMP with label: Little
#   Loaded image: 486__M_Left_little_finger.BMP with label: Little
#   Loaded image: 99__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 107__M_Left_little_finger.BMP with label: Little
#   Loaded image: 233__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 105__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 106__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 445__M_Right_index_finger.BMP with label: Index
#   Loaded image: 475__M_Left_index_finger.BMP with label: Index
#   Loaded image: 217__M_Right_index_finger.BMP with label: Index
#   Loaded image: 584__M_Right_index_finger.BMP with label: Index
#   Loaded image: 135__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 371__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 177__F_Left_index_finger.BMP with label: Index
#   Loaded image: 28__M_Left_little_finger.BMP with label: Little
#   Loaded image: 313__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 397__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 385__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 498__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 377__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 343__M_Right_index_finger.BMP with label: Index
#   Loaded image: 532__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 428__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 141__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 158__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 319__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 78__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 130__F_Right_index_finger.BMP with label: Index
#   Loaded image: 474__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 164__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 198__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 117__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 533__M_Left_little_finger.BMP with label: Little
#   Loaded image: 247__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 443__M_Right_index_finger.BMP with label: Index
#   Loaded image: 518__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 582__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 501__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 420__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 47__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 455__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 598__M_Left_little_finger.BMP with label: Little
#   Loaded image: 6__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 165__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 79__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 280__M_Right_little_finger.BMP with label: Little
#   Loaded image: 95__M_Left_little_finger.BMP with label: Little
#   Loaded image: 98__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 589__M_Left_little_finger.BMP with label: Little
#   Loaded image: 33__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 438__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 155__M_Right_little_finger.BMP with label: Little
#   Loaded image: 246__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 63__M_Left_little_finger.BMP with label: Little
#   Loaded image: 411__M_Right_index_finger.BMP with label: Index
#   Loaded image: 466__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 8__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 556__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 293__F_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 83__M_Left_index_finger.BMP with label: Index
#   Loaded image: 15__F_Right_index_finger.BMP with label: Index
#   Loaded image: 535__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 271__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 299__M_Left_little_finger.BMP with label: Little
#   Loaded image: 287__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 264__M_Right_index_finger.BMP with label: Index
#   Loaded image: 59__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 347__M_Left_index_finger.BMP with label: Index
#   Loaded image: 35__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 87__M_Left_little_finger.BMP with label: Little
#   Loaded image: 591__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 566__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 494__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 189__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 137__M_Right_little_finger.BMP with label: Little
#   Loaded image: 77__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 282__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 63__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 289__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 460__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 541__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 249__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 498__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 151__M_Right_index_finger.BMP with label: Index
#   Loaded image: 196__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 551__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 335__M_Left_little_finger.BMP with label: Little
#   Loaded image: 130__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 102__M_Right_index_finger.BMP with label: Index
#   Loaded image: 31__F_Right_middle_finger.BMP with label: Middle
#   Loaded image: 132__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 350__M_Left_little_finger.BMP with label: Little
#   Loaded image: 125__M_Right_little_finger.BMP with label: Little
#   Loaded image: 324__M_Right_index_finger.BMP with label: Index
#   Loaded image: 157__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 543__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 408__M_Right_little_finger.BMP with label: Little
#   Loaded image: 275__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 228__M_Right_little_finger.BMP with label: Little
#   Loaded image: 318__F_Left_little_finger.BMP with label: Little
#   Loaded image: 181__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 461__F_Right_little_finger.BMP with label: Little
#   Loaded image: 187__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 219__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 306__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 435__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 123__M_Left_index_finger.BMP with label: Index
#   Loaded image: 457__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 84__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 120__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 338__M_Left_little_finger.BMP with label: Little
#   Loaded image: 288__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 11__M_Right_little_finger.BMP with label: Little
#   Loaded image: 19__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 456__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 527__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 463__F_Left_index_finger.BMP with label: Index
#   Loaded image: 20__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 316__M_Left_index_finger.BMP with label: Index
#   Loaded image: 436__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 472__M_Right_little_finger.BMP with label: Little
#   Loaded image: 204__F_Left_index_finger.BMP with label: Index
#   Loaded image: 272__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 23__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 584__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 256__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 42__F_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 33__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 389__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 57__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 18__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 323__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 458__M_Right_index_finger.BMP with label: Index
#   Loaded image: 367__M_Left_little_finger.BMP with label: Little
#   Loaded image: 81__F_Left_little_finger.BMP with label: Little
#   Loaded image: 568__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 459__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 496__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 235__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 544__M_Right_index_finger.BMP with label: Index
#   Loaded image: 198__M_Right_index_finger.BMP with label: Index
#   Loaded image: 273__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 244__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 430__F_Left_ring_finger.BMP with label: Ring
#   Loaded image: 115__F_Left_middle_finger.BMP with label: Middle
#   Loaded image: 61__M_Right_little_finger.BMP with label: Little
#   Loaded image: 429__M_Right_little_finger.BMP with label: Little
#   Loaded image: 432__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 263__F_Left_little_finger.BMP with label: Little
#   Loaded image: 4__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 191__F_Right_ring_finger.BMP with label: Ring
#   Loaded image: 197__M_Right_ring_finger.BMP with label: Ring
#   Loaded image: 101__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 457__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 341__M_Right_little_finger.BMP with label: Little
#   Loaded image: 16__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 291__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 333__M_Left_index_finger.BMP with label: Index
#   Loaded image: 199__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 565__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 578__M_Right_little_finger.BMP with label: Little
#   Loaded image: 439__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 430__F_Right_index_finger.BMP with label: Index
#   Loaded image: 138__M_Left_thumb_finger.BMP with label: Thumb
#   Loaded image: 280__M_Left_little_finger.BMP with label: Little
#   Loaded image: 277__M_Left_index_finger.BMP with label: Index
#   Loaded image: 294__M_Left_little_finger.BMP with label: Little
#   Loaded image: 490__M_Right_thumb_finger.BMP with label: Thumb
#   Loaded image: 111__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 445__M_Left_index_finger.BMP with label: Index
#   Loaded image: 443__M_Left_ring_finger.BMP with label: Ring
#   Loaded image: 227__M_Left_middle_finger.BMP with label: Middle
#   Loaded image: 307__M_Right_middle_finger.BMP with label: Middle
#   Loaded image: 82__M_Right_index_finger.BMP with label: Index
# Loaded 6000 images total.
# Training set: 4199 images, Validation set: 901 images, Test set: 900 images
# /home/zaman-m65/miniconda3/envs/my_env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/zaman-m65/miniconda3/envs/my_env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/100], Loss: 1.2515
# Epoch [2/100], Loss: 0.8896
# Epoch [3/100], Loss: 0.7669
# Epoch [4/100], Loss: 0.7139
# Epoch [5/100], Loss: 0.6341
# Epoch [6/100], Loss: 0.6147
# Epoch [7/100], Loss: 0.5517
# Epoch [8/100], Loss: 0.5359
# Epoch [9/100], Loss: 0.4784
# Epoch [10/100], Loss: 0.4362
# Epoch [11/100], Loss: 0.4032
# Epoch [12/100], Loss: 0.4131
# Epoch [13/100], Loss: 0.3855
# Epoch [14/100], Loss: 0.3394
# Epoch [15/100], Loss: 0.3181
# Epoch [16/100], Loss: 0.3045
# Epoch [17/100], Loss: 0.2829
# Epoch [18/100], Loss: 0.2770
# Epoch [19/100], Loss: 0.2689
# Epoch [20/100], Loss: 0.2239
# Epoch [21/100], Loss: 0.2340
# Epoch [22/100], Loss: 0.2204
# Epoch [23/100], Loss: 0.1807
# Epoch [24/100], Loss: 0.1873
# Epoch [25/100], Loss: 0.1863
# Epoch [26/100], Loss: 0.1765
# Epoch [27/100], Loss: 0.1410
# Epoch [28/100], Loss: 0.1564
# Epoch [29/100], Loss: 0.1588
# Epoch [30/100], Loss: 0.1332
# Epoch [31/100], Loss: 0.1363
# Epoch [32/100], Loss: 0.1303
# Epoch [33/100], Loss: 0.1230
# Epoch [34/100], Loss: 0.1440
# Epoch [35/100], Loss: 0.1341
# Epoch [36/100], Loss: 0.1096
# Epoch [37/100], Loss: 0.0910
# Epoch [38/100], Loss: 0.0904
# Epoch [39/100], Loss: 0.1076
# Epoch [40/100], Loss: 0.1038
# Epoch [41/100], Loss: 0.1108
# Epoch [42/100], Loss: 0.1006
# Epoch [43/100], Loss: 0.0842
# Epoch [44/100], Loss: 0.0887
# Epoch [45/100], Loss: 0.0774
# Epoch [46/100], Loss: 0.0911
# Epoch [47/100], Loss: 0.0950
# Epoch [48/100], Loss: 0.0796
# Epoch [49/100], Loss: 0.0733
# Epoch [50/100], Loss: 0.0974
# Epoch [51/100], Loss: 0.0978
# Epoch [52/100], Loss: 0.0776
# Epoch [53/100], Loss: 0.0692
# Epoch [54/100], Loss: 0.0566
# Epoch [55/100], Loss: 0.0723
# Epoch [56/100], Loss: 0.0715
# Epoch [57/100], Loss: 0.0707
# Epoch [58/100], Loss: 0.0791
# Epoch [59/100], Loss: 0.0671
# Epoch [60/100], Loss: 0.0797
# Epoch [61/100], Loss: 0.0681
# Epoch [62/100], Loss: 0.0517
# Epoch [63/100], Loss: 0.0546
# Epoch [64/100], Loss: 0.0606
# Epoch [65/100], Loss: 0.0666
# Epoch [66/100], Loss: 0.0551
# Epoch [67/100], Loss: 0.0515
# Epoch [68/100], Loss: 0.0551
# Epoch [69/100], Loss: 0.0638
# Epoch [70/100], Loss: 0.0616
# Epoch [71/100], Loss: 0.0657
# Epoch [72/100], Loss: 0.0429
# Epoch [73/100], Loss: 0.0466
# Epoch [74/100], Loss: 0.0545
# Epoch [75/100], Loss: 0.0621
# Epoch [76/100], Loss: 0.0572
# Epoch [77/100], Loss: 0.0409
# Epoch [78/100], Loss: 0.0489
# Epoch [79/100], Loss: 0.0535
# Epoch [80/100], Loss: 0.0465
# Epoch [81/100], Loss: 0.0484
# Epoch [82/100], Loss: 0.0480
# Epoch [83/100], Loss: 0.0552
# Epoch [84/100], Loss: 0.0406
# Epoch [85/100], Loss: 0.0625
# Epoch [86/100], Loss: 0.0341
# Epoch [87/100], Loss: 0.0457
# Epoch [88/100], Loss: 0.0591
# Epoch [89/100], Loss: 0.0443
# Epoch [90/100], Loss: 0.0372
# Epoch [91/100], Loss: 0.0366
# Epoch [92/100], Loss: 0.0564
# Epoch [93/100], Loss: 0.0412
# Epoch [94/100], Loss: 0.0482
# Epoch [95/100], Loss: 0.0451
# Epoch [96/100], Loss: 0.0438
# Epoch [97/100], Loss: 0.0425
# Epoch [98/100], Loss: 0.0382
# Epoch [99/100], Loss: 0.0325
# Epoch [100/100], Loss: 0.0393
# Training complete.
# Test Accuracy: 0.78
# Test F1 Score: 0.78

# %%
# Plot class distribution
plot_class_distribution(pipeline.y_train, pipeline.y_val, pipeline.y_test)

# %%
# Plot confusion matrix & classification report
plot_confusion_matrix_and_report(pipeline, normalize=None, save_path='confusion_matrix.png')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        Index       0.71      0.88      0.79       180
#       Little       0.77      0.78      0.77       180
#       Middle       0.73      0.58      0.64       180
#         Ring       0.72      0.72      0.72       180
#        Thumb       0.97      0.94      0.95       180
#
#     accuracy                           0.78       900
#    macro avg       0.78      0.78      0.78       900
# weighted avg       0.78      0.78      0.78       900

# %%
import matplotlib.pyplot as plt
import torch
import cv2
import numpy as np
import kornia                      # already installed
from torchvision import transforms # reuse the eval_transform

# ──────────────────────────────────────────────────────────────────────────
def single_image_inference_with_visuals(pipeline, image_path):
    """
    • Shows original ↔︎ edge‑map side‑by‑side.
    • Runs the EfficientNet‑edge model and prints class probabilities.
    Works with the CURRENT pipeline (no external feature_extractor).
    """
    # ------------------------------------------------ load image
    img_bgr = cv2.imread(image_path)
    if img_bgr is None:
        print(f"❌  Could not read image: {image_path}")
        return None, None

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # ------------------------------------------------ build edge map for display
    img_t_edge = transforms.ToTensor()(cv2.resize(img_rgb, (224, 224))).unsqueeze(0).to(device)
    gray       = kornia.color.rgb_to_grayscale(img_t_edge)
    blur       = kornia.filters.gaussian_blur2d(gray, (5,5), (1.0,1.0))
    sobel      = kornia.filters.sobel(blur)
    edge_map   = torch.sqrt((sobel**2).sum(dim=1, keepdim=True))[0,0].cpu().numpy()

    # ------------------------------------------------ model inference
    input_tensor = eval_transform(img_rgb).unsqueeze(0).to(device)   # [1,3,224,224]
    trainer      = pipeline.model_trainer
    trainer.model.eval()
    with torch.no_grad():
        logits = trainer.model(input_tensor)                         # [1,num_classes]
        probs  = torch.softmax(logits, dim=1)[0].cpu().numpy()       # [num_classes]

    idx          = int(probs.argmax())
    pred_label   = trainer.idx_to_label[idx]
    class_labels = [trainer.idx_to_label[i] for i in range(len(probs))]
    prob_dict    = {lbl: float(p) for lbl, p in zip(class_labels, probs)}

    # ------------------------------------------------ side‑by‑side display
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1); plt.imshow(img_rgb);  plt.title("Original"); plt.axis("off")
    plt.subplot(1,2,2); plt.imshow(edge_map, cmap="gray"); plt.title("Edge map"); plt.axis("off")
    plt.suptitle(f"Predicted: {pred_label}", fontsize=14)
    plt.show()

    # ------------------------------------------------ console print‑out
    print("Probabilities:")
    for cls, pr in prob_dict.items():
        print(f"  {cls:<7}: {pr:.4f}")

    return pred_label, prob_dict
# ──────────────────────────────────────────────────────────────────────────

# %%
test_img = os.path.expanduser(
    "~/data/SOCOFing/Real/281__M_Left_index_finger.BMP")

label, probs = single_image_inference_with_visuals(pipeline, test_img)

print("Predicted label =", label)        # show the label in console
print("Probabilities  =", probs)         # full probability dict
# Out:
# Probabilities:
#   Index  : 1.0000
#   Little : 0.0000
#   Middle : 0.0000
#   Ring   : 0.0000
#   Thumb  : 0.0000
# Predicted label = Index
# Probabilities  = {'Index': 0.999988317489624, 'Little': 4.326205171878428e-08, 'Middle': 9.220376995244806e-08, 'Ring': 1.1368655577825848e-05, 'Thumb': 1.0236011149800106e-07}

# %%
test_img = os.path.expanduser(
    "~/data/SOCOFing/Real/45__M_Right_little_finger.BMP")

label, probs = single_image_inference_with_visuals(pipeline, test_img)

print("Predicted label =", label)        # show the label in console
print("Probabilities  =", probs)         # full probability dict
# Out:
# Probabilities:
#   Index  : 0.0001
#   Little : 0.9999
#   Middle : 0.0000
#   Ring   : 0.0000
#   Thumb  : 0.0000
# Predicted label = Little
# Probabilities  = {'Index': 0.00010015822044806555, 'Little': 0.9998911619186401, 'Middle': 6.365290232679399e-07, 'Ring': 7.155026196414838e-06, 'Thumb': 8.39317294776265e-07}

# %%
test_img = os.path.expanduser(
    "~/data/SOCOFing/Real/279__M_Left_middle_finger.BMP")

label, probs = single_image_inference_with_visuals(pipeline, test_img)

print("Predicted label =", label)        # show the label in console
print("Probabilities  =", probs)         # full probability dict
# Out:
# Probabilities:
#   Index  : 0.0000
#   Little : 0.0000
#   Middle : 1.0000
#   Ring   : 0.0000
#   Thumb  : 0.0000
# Predicted label = Middle
# Probabilities  = {'Index': 2.5921856376953656e-06, 'Little': 1.0555146978674657e-08, 'Middle': 0.9999973773956299, 'Ring': 2.2153768597377166e-08, 'Thumb': 3.9777705435062316e-11}

# %%
test_img = os.path.expanduser(
    "~/data/SOCOFing/Real/27__M_Right_thumb_finger.BMP")

label, probs = single_image_inference_with_visuals(pipeline, test_img)

print("Predicted label =", label)        # show the label in console
print("Probabilities  =", probs)         # full probability dict
# Out:
# Probabilities:
#   Index  : 0.0000
#   Little : 0.0000
#   Middle : 0.0000
#   Ring   : 0.0000
#   Thumb  : 1.0000
# Predicted label = Thumb
# Probabilities  = {'Index': 3.893963818057955e-09, 'Little': 6.691438202144351e-12, 'Middle': 2.0404156586550926e-08, 'Ring': 1.4281482663136558e-07, 'Thumb': 0.9999998807907104}

# %%
test_img = os.path.expanduser(
    "~/data/SOCOFing/Real/98__M_Right_ring_finger.BMP")

label, probs = single_image_inference_with_visuals(pipeline, test_img)

print("Predicted label =", label)        # show the label in console
print("Probabilities  =", probs)         # full probability dict
# Out:
# Probabilities:
#   Index  : 0.0000
#   Little : 0.0001
#   Middle : 0.0001
#   Ring   : 0.9998
#   Thumb  : 0.0000
# Predicted label = Ring
# Probabilities  = {'Index': 5.303635930431483e-07, 'Little': 9.420023707207292e-05, 'Middle': 8.210963278543204e-05, 'Ring': 0.9998229146003723, 'Thumb': 3.7046399370410654e-07}

# %%
test_img = os.path.expanduser("~/data/SOCOFing/Real/270__M_Left_ring_finger.BMP")
pred, probs = single_image_inference_with_visuals(pipeline, test_img)
# Out:
# Probabilities:
#   Index  : 0.8579
#   Little : 0.0229
#   Middle : 0.0946
#   Ring   : 0.0245
#   Thumb  : 0.0002
